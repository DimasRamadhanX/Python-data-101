# %% [markdown]
# # Predictive Modeling and Analytics - Tutorial 1
# ![download (17).png](data:image/png;base64,...)
# - Pengenalan Python
# - Praproses Data
# - Eksplorasi Data

# %% [markdown]
# ## **Pengenalan Python**
# Python merupakan bahasa pemrograman tingkat tinggi yang mudah digunakan. Kemudahan ini membuat python menjadi bahasa pemrogramman yang sangat populer saat ini. Python banyak diterapkan dalam pembuatan web, aplikasi dan keperluan lainnya. Hal yang paling sering menjadi alasan untuk menggunakan Python ini adalah kemudahannya digunakan dalam dunia Data Science.

# %% [markdown]
# ### Mengapa Python?
# 1. Easy to learn
# 2. Interpreted language
# 3. Extensive library

# %% [markdown]
# ### Mengenal Library Python
# **NumPy**
#
# Library Numpy merupakan Library yang sering digunakan dalam mengolah data array dan pengolahannya secara matematis. Di Python sendiri tidak mendukung pengolahan array, namun ada tipe data list namun penggunaannya tidak sefleksibel dan semudah array dari Numpy
#
# **Pandas**
#
# Pandas merupakan library yang digunakan dalam pengolahan DataFrame. DataFrame umumnya seperti tabel yang berisi kolom dan baris. Sehingga Pandas ini cocok digunakan dalam menganalisa data yang berupa tabel. Pandas juga sering digunakan dalam melakukan praproses data seperti penanganan data hilang, pembanding data, menggabungkan data, merubah bentuk data dsb.
#
# **Matplotlib & Seaborn**
#
# Library ini digunakan untuk melakukan visualisasi data. Visualisasi ini bisa berupa histogram, scatter plot dan sebagainya sesuai kebutuhan. Perbedaan Matplotlib dan Seaborn adalah di mana Seaborn dibangun di atas Matplotlib.
#
# **Scikit-Learn (sklearn)**
#
# Library ini digunakan untuk melakukan proses Machine Learning pada Python. Fungsi-fungsi di dalamnya cukup lengkap baik untuk Klasifikasi, Klasterisasi dan Regresi. Seaborn juga memiliki sejumlah dataset sederhana yang bisa digunakan pada library-nya
#
# **Keras, TensorFlow, PyTorch**
#
# Library-library ini berfokus pada Deep Learning (subset dari Machine Learning). Ketiganya biasa digunakan dalam menerapkan metode Neural Network.

# %% [markdown]
# ### Ngoding Python dimana?
# * Google Colaboratory, Kaggle **(Online)**
#
# * Jupyter Notebook, PyCharm, Spyder **(Offline)**

# %% [markdown]
# Teman-teman bisa mengakses notebook ini pada [tekan.id/NotebookTutorial1PMA](https://tekan.id/NotebookTutorial1PMA)

# %% [markdown]
# **hotkeys dalam Google Colab:**
#
# * Ctrl + / for block-comments line(s) of code
# * Ctrl + \[ or Ctrl + \] for changing the indentation
# * Shift + Enter for running the current code cell

# %%
print("tekan Ctrl dan / bersamaan")

print("tekan Ctrl dan [ atau ] untuk menggeser indent")

print("tekan Shift dan Enter untuk menjalankan cell kode ini")
# Out:
# tekan Ctrl dan / bersamaan
# tekan Ctrl dan [ atau ] untuk menggeser indent
# tekan Shift dan Enter untuk menjalankan cell kode ini

# %% [markdown]
# ### Tipe-tipe Data di Python
#
# *   NoneType
# *   Integer
# *   Float (decimal)
# *   Complex (imaginary number)
# *   Boolean
# *   String

# %%
# None
a = None
print(a)
# Out:
# None

# %%
# Numeric
i = 1  # Integer (bilangan bulat)
f = 1.0  # Float (bilangan decimal)
c = 2+1j  # Complex (bilangan kompleks)

print('i:', i, type(i))
print('f:', f, type(f))
print('c:', c, type(c))
# Out:
# i: 1 <class 'int'>
# f: 1.0 <class 'float'>
# c: (2+1j) <class 'complex'>

# %%
# Ubah tipe data (casting)
u = 7.7

a1 = float(u)  # Ubah tipe data menjadi float
b1 = int(u)  # Ubah tipe data menjadi int (jika float diubah ke int maka dibulatkan ke bawah)
c1 = complex(u)  # Ubah tipe data menjadi complex

print(a1)
print(b1)
print(c1)
# Out:
# 7.7
# 7
# (7.7+0j)

# %%
# Boolean
t = True
f = False
t_int = int(t)
f_int = int(f)

print('t:',t, type(t))
print('f:',f, type(f))
print('True =', t_int)
print('False =', f_int)
print('t and f:', (t & f))
print('t or f:', (t | f))
print()

# Operasi komparasi
k1 = (1 < 2)
k2 = (2 > 1)
k3 = (2 <= 3)
k4 = (4 >= 3)
k5 = (2 == 2)
k6 = (3 != 4)
k7 = (7 > 5) and (6 > 7)  # and
k8 = (7 > 5) or (6 > 7)  # or
k9 = not True  # not, hasilnya false

print('(1 < 2) =', k1, type(k1))
print('(2 > 1) =', k2)
print('(2 <= 3) =', k3)
print('(4 >= 3) =', k4)
print('(2 == 2) =', k5)
print('(3 != 4) =', k6)
print('(4 > 5) and (6 > 7) =', k7)
print('(4 > 5) or (6 > 7) =', k8)
print('not True =', k9)
# Out:
# t: True <class 'bool'>
# f: False <class 'bool'>
# True = 1
# False = 0
# t and f: False
# t or f: True
#
# (1 < 2) = True <class 'bool'>
# (2 > 1) = True
# (2 <= 3) = True
# (4 >= 3) = True
# (2 == 2) = True
# (3 != 4) = True
# (4 > 5) and (6 > 7) = False
# (4 > 5) or (6 > 7) = True
# not True = False

# %%
# String
s = "hello"
t = 'guys'
u = "what's up"

print(u)
print(s + t)
# Out:
# what's up
# helloguys

# %%
w1 = "Hi {} !".format(t)
w2 = f"Hi {t} {u} !"
w3 = "Hi %s !" % t # 's' in '%s' stands for 'string data type'
w4 = "Decimal number: {:.2f}".format(2.50000) # :.2f means we only want the number with 2 decimals

print(w1)
print(w2)
print(w3)
print(w4)
# Out:
# Hi guys !
# Hi guys what's up !
# Hi guys !
# Decimal number: 2.50

# %%
# Ubah tipe data

nilai = "1.0"
print(nilai, type(nilai))
# print(int(nilai)) # will result in error
print(int(float(nilai))) #kalau string berupa desimal maka harus diubah dulu menjadi float baru kemudian diubah ke integer

a = 1
a = str(a)
print(a, type(a))
# Out:
# 1.0 <class 'str'>
# 1
# 1 <class 'str'>

# %% [markdown]
# ## **Hands-on 1**
# Setelah ini, silakan teman-teman mulai untuk mengikuti langkah-langkah seperti yang ditunjukkan di notebook untuk melakukan kegiatan dasar dari **eksplorasi dan praproses data.**

# %% [markdown]
# ## **1. Import Libraries**
# Dalam penggunaan Google Colab, sebelum menggunakan fitur-fitur yang tersedia dalam library yang sudah dijelaskan sebelumnya (NumPy, Matplotlib, dsb.), library yang ingin digunakan harus di-import terlebih dahulu demgam menggunakan syntax:
#
# `import namaLibrary as abc`
#
# Bagian syntax "as abc" opsional, namun khususnya bagian "abc" biasanya sudah ada best practice penamaan library (Seperti np untuk NumPy, pd untuk Pandas, dsb.) dan akan teman-teman gunakan untuk "memanggil" fungsi (fitur) yang ditawarkan sebuah library.

# %%
# Import Library Python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# the help() function is a built-in function that provides information about modules, classes, functions, and modules.
help(plt.autumn)
# Out:
# Help on function autumn in module matplotlib.pyplot:
#
# autumn() -> 'None'
#     Set the colormap to 'autumn'.
#
#     This changes the default colormap as well as the colormap of the current
#     image if there is one. See ``help(colormaps)`` for more information.

# %%
pd.set_option('display.max_columns',None) # to see ALL COLUMNS in a DataFrame table. 'None' means there is no limit for displayed columns.
# pd.set_option('display.max_rows',None) # to see ALL ROWS in a DataFrame table.

# %% [markdown]
# ## **2. Import dataset**
# Untuk melakukan eksplorasi data, pertama-tama kita harus mengimpor dataset ke dalam runtime agar dapat dilakukan berbagai macam operasi. Ada 3 cara import file, antara lain:
# * Upload langsung ke Google Colab
# * Mounting Google Drive
# * Import pre-loaded dataset dari Library tertentu
#
# Dalam praktik kali ini, kita akan mencoba untuk meng-import data iris_dataset.csv ke dalam Google Colab.

# %% [markdown]
# #### Import via upload file (in Google Colab)

# %% [markdown]
# Untuk meng-upload files secara langsung ke dalam Google Colab, teman-teman dapat membuka terlebih dahulu sidebar berjudul "Files" di layar samping Google Colab. Kemudian akan muncul menu bar, dimana teman-teman dapat menekan tombol "Upload to session storage" kemudian memilih file yang hendak di upload, atau melakukan drag & drop secara langsung ke bagian kosong di bagian Files.
#
# Setelah meng-upload file, kita dapat menggunakan library Pandas untuk "membacakan" isi dari dataset yang sudah kita upload dengan syntax sebagai berikut:
#
# `iris = pd.read_csv('iris_dataset.csv')`
#
# kemudian untuk memanggil isi variabel "iris" kita dapat menggunakan:
#
# `iris`

# %% [markdown]
# Data dapat di-download pada drive berikut:
#
# <!-- [Drive Dataset](https://drive.google.com/drive/folders/1wOqWjZ9SlDkT9qQSvfcxU7EFUdAoLjQ0?usp=sharing) -->
# [Drive Dataset](https://gist.github.com/netj/8836201)

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# memberikan header pada dataset (kalau dataset belum memiliki header)


# rename columns at the same time 'when' importing dataset
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
data_iris = pd.read_csv('iris.csv', names = colnames)


# rename columns 'after' importing dataset
data_iris = pd.read_csv('iris.csv')
data_iris.columns = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']


# rename SPECIFIC COLUMN(S) only
data_iris.rename(columns={'sepal-length':'sepal-length', 'sepal-width':'sepal-width'}, inplace=True) # "inplace=True" means:
                                                                                                     # you don't need to assign it to a variable
                                                                                                     # it directly changes its DataFrame
# data_iris = data_iris.rename(columns={'sepal-length':'sepal-length', 'sepal-width':'sepal-width'})

data_iris
# Out:
#      sepal-length  sepal-width  petal-length  petal-width      class
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Import dengan menghubungkan/mount ke Google Drive (in Google Colab)
#
# (click on **Mount Drive** button and <u>Accept</u> Google Colab permission to access your GDrive)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/drive/MyDrive/" # > COPY PATH from your project FOLDER on GDrive & add '/' in the end
                                                                      # > save this PATH Variable, in case we need to import another file from this Folder

iris = pd.read_csv(path + "Iris.csv")
iris

# %%
# drop column 'id'
# data_iris = iris.drop(columns= "Id")

# rename column name
data_iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Import pre-loaded dataset via library

# %%
# dataset yang memang dimiliki library Seaborn (pre-loaded dataset)
data_iris = sns.load_dataset("Iris")

# %%
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Import data apabila Menggunakan Jupyter Notebook

# %%
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# drop column 'id'
# data_iris = iris.drop(columns= "Id")

# rename column name
data_iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## **3. Praproses Data**
# Data Preprocessing adalah kegiatan pengolahan data agar dapat dioperasikan secara lebih lanjut. Secara umum, kegiatan ini bisa disebut juga dengan "data cleansing" dimana kita mengolah data yang kotor (value yang hilang, duplikat, outlier) menjadi data bersih.

# %% [markdown]
# ### Data kotor? Kotor bagaimana maksudnya?
#
# - Data duplikat: satu baris data yang muncul lebih dari satu kali
# - Data tidak lengkap: beberapa field berisi null value
# - Data tidak konsisten: data dalam format yang salah atau format yang berbeda-beda

# %% [markdown]
# ![link text](https://blog.databas.nl/hs-fs/hub/242743/file-2400159258-jpg/garbage-in-garbage-out.jpg)

# %% [markdown]
# Kita akan melakukan praproses data menggunakan library Pandas. Dokumentasi library dapat diakses pada link berikut ini:
#
# [Dokumentasi Pandas](https://pandas.pydata.org/docs/reference/index.html)

# %% [markdown]
# Jalankan kode berikut ini untuk membuat dummy data yang belum bersih.

# %%
# Membuat data frame
nama = ["Aida", "Beta", "Charlie", "Doni", "Eka", "Firda", "Gina", "Hera", "Indra", "Janet", "Eka"]
nilai = [75, 66, 80, 33, 80, 99, 67, 56, 89, 75, 80]
kelas = [np.nan, np.nan, np.nan, np.nan, 'B', 'A', np.nan, np.nan, 'C', np.nan, 'B']
jurusan = ['IPA', 'IPA', 'IPS', 'IPA', 'IPS', np.nan, 'IPA', 'IPA', 'IPA', 'IPA', 'IPS']
ekonomi = ["Mampu", "Kurang Mampu", "Kurang Mampu", "Menengah", "Menengah", "Mampu", "Kurang Mampu", "Mampu", "Mampu", "Menengah", "Menengah"]
beasiswa = ["Tidak", "Ya", "Ya", "Tidak", "Tidak", "Ya", "Tidak", "Ya", "Tidak", "Ya", "Tidak"]

data_kelas = pd.DataFrame(data = {'nama':nama,
                                  'nilai':nilai,
                                  'kelas':kelas,
                                  'jurusan':jurusan,
                                  'ekonomi':ekonomi,
                                  'beasiswa':beasiswa})
data_kelas
# Out:
#        nama  nilai kelas jurusan       ekonomi beasiswa
# 0      Aida     75   NaN     IPA         Mampu    Tidak
# 1      Beta     66   NaN     IPA  Kurang Mampu       Ya
# 2   Charlie     80   NaN     IPS  Kurang Mampu       Ya
# 3      Doni     33   NaN     IPA      Menengah    Tidak
# 4       Eka     80     B     IPS      Menengah    Tidak
# 5     Firda     99     A     NaN         Mampu       Ya
# 6      Gina     67   NaN     IPA  Kurang Mampu    Tidak
# 7      Hera     56   NaN     IPA         Mampu       Ya
# 8     Indra     89     C     IPA         Mampu    Tidak
# 9     Janet     75   NaN     IPA      Menengah       Ya
# 10      Eka     80     B     IPS      Menengah    Tidak

# %%
# Menampilkan tipe data masing-masing kolom
data_kelas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nama      11 non-null     object
#  1   nilai     11 non-null     int64
#  2   kelas     4 non-null      object
#  3   jurusan   10 non-null     object
#  4   ekonomi   11 non-null     object
#  5   beasiswa  11 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 660.0+ bytes

# %% [markdown]
# Perhatikan pada hasil `info()` diatas, pada bagian Non-Null Count, terlihat bahwa terdapat perbedaan pada jumlah data non-null pada tiap kolomnya. Hal ini mengindikasikan terdapat null value dalam dataset.

# %% [markdown]
# ### Pemeriksaan Missing Value

# %%
# Cek apakah terdapat baris yang kosong
data_kelas.isnull().sum()
# Out:
# nama        0
# nilai       0
# kelas       7
# jurusan     1
# ekonomi     0
# beasiswa    0
# dtype: int64

# %% [markdown]
# `isnull()` akan memberikan output berupa baris-baris data mana saja yang mengandung null value di dalamnya.
#
# Ketika `sum()` ditambahkan, akan diberikan output berupa jumlah (sum) dari baris-baris data yang mengandung null value.

# %% [markdown]
# #### Mengatasi Missing Value

# %% [markdown]
# Untuk mengatasi missing value, beberapa solusi dapat dilakukan.
# - Menghapus missing value/sparse columns (kolom yang berisi banyak null)
# - Mengisi missing value dengan nilai mayoritas (mean, median, mode)

# %% [markdown]
# Berdasarkan informasi yang sebelumnya didapat, dalam kolom kelas hanya terdapat 4 baris data yang memiliki value. Hampir seluruhnya berisi null value. Maka, kita dapat menghapus kolom kelas.

# %%
# Hapus kolom yang memiliki banyak nilai kosong
dk = data_kelas.drop(columns='kelas')
dk
# Out:
#        nama  nilai jurusan       ekonomi beasiswa
# 0      Aida     75     IPA         Mampu    Tidak
# 1      Beta     66     IPA  Kurang Mampu       Ya
# 2   Charlie     80     IPS  Kurang Mampu       Ya
# 3      Doni     33     IPA      Menengah    Tidak
# 4       Eka     80     IPS      Menengah    Tidak
# 5     Firda     99     NaN         Mampu       Ya
# 6      Gina     67     IPA  Kurang Mampu    Tidak
# 7      Hera     56     IPA         Mampu       Ya
# 8     Indra     89     IPA         Mampu    Tidak
# 9     Janet     75     IPA      Menengah       Ya
# 10      Eka     80     IPS      Menengah    Tidak

# %% [markdown]
# Pada kolom jurusan, hanya terdapat 1 null value, tidak selayaknya apabila kita hapus keseluruhan kolom. Maka, kita dapat mengisi null value tersebut dengan nilai yang paling sering muncul.

# %%
dk['jurusan'].value_counts()
# Out:
# jurusan
# IPA    7
# IPS    3
# Name: count, dtype: int64

# %% [markdown]
# `value_counts()` akan memberikan output berupa frekuensi suatu nilai muncul.

# %%
# memberikan nilai pada baris kosong
jurusan_max = dk['jurusan'].value_counts().idxmax()
dk['jurusan'] = dk['jurusan'].fillna(jurusan_max)
dk
# Out:
#        nama  nilai jurusan       ekonomi beasiswa
# 0      Aida     75     IPA         Mampu    Tidak
# 1      Beta     66     IPA  Kurang Mampu       Ya
# 2   Charlie     80     IPS  Kurang Mampu       Ya
# 3      Doni     33     IPA      Menengah    Tidak
# 4       Eka     80     IPS      Menengah    Tidak
# 5     Firda     99     IPA         Mampu       Ya
# 6      Gina     67     IPA  Kurang Mampu    Tidak
# 7      Hera     56     IPA         Mampu       Ya
# 8     Indra     89     IPA         Mampu    Tidak
# 9     Janet     75     IPA      Menengah       Ya
# 10      Eka     80     IPS      Menengah    Tidak

# %% [markdown]
# `idxmax()` memberikan output berupa index dari data tertinggi, dalam kasus ini adalah 'IPA'.
#
# `fillna()` akan mengisi null value dengan nilai yang dipilih.

# %%
# Periksa kembali data
dk.isnull().sum()
# Out:
# nama        0
# nilai       0
# jurusan     0
# ekonomi     0
# beasiswa    0
# dtype: int64

# %% [markdown]
# In missing-data imputation, the <u>*tradeoff*</u> between **dropping sparse columns** and **filling missing values**:
#
# * *dropping sparse column* (column with lots of missing values): in some cases, it could be that this column may still hold essential information
#
# * *filling missing values* with mode/mean/median: may not really represent the actual data

# %% [markdown]
# ### Pemeriksaan Data Duplikat
#
# Duplicates **can add the weights of samples and can cause bias**, hence it's recommended to remove duplicated rows.
#
# ( https://www.quora.com/Should-I-remove-duplicates-from-a-data-set-in-machine-learning )

# %% [markdown]
# `duplicated()` akan menunjukkan baris mana yang terduplikasi (nilai tiap kolomnya sama dengan baris sebelum-sebelumnya)

# %%
jumlah_baris_duplikat = dk.duplicated().sum()
print("Jumlah baris yang memiliki data sama: {} baris".format(jumlah_baris_duplikat))
# Out:
# Jumlah baris yang memiliki data sama: 1 baris

# %%
dk.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# dtype: bool

# %% [markdown]
# Kita dapat mengatasi duplikasi data dengan menghapus data yang terduplikat.
#
# `drop_duplicates()` akan menghapus baris-baris yang terduplikasi.

# %%
dk_new = dk.drop_duplicates()
dk_new
# Out:
#       nama  nilai jurusan       ekonomi beasiswa
# 0     Aida     75     IPA         Mampu    Tidak
# 1     Beta     66     IPA  Kurang Mampu       Ya
# 2  Charlie     80     IPS  Kurang Mampu       Ya
# 3     Doni     33     IPA      Menengah    Tidak
# 4      Eka     80     IPS      Menengah    Tidak
# 5    Firda     99     IPA         Mampu       Ya
# 6     Gina     67     IPA  Kurang Mampu    Tidak
# 7     Hera     56     IPA         Mampu       Ya
# 8    Indra     89     IPA         Mampu    Tidak
# 9    Janet     75     IPA      Menengah       Ya

# %%
x = dk_new['jurusan']
y = dk_new['nama']
plt.bar(x, y)
plt.show()

# %%
jumlah_baris_duplikat = dk_new.duplicated().sum()
print("Jumlah baris yang memiliki data sama: {} baris".format(jumlah_baris_duplikat))
# Out:
# Jumlah baris yang memiliki data sama: 0 baris

# %%
dk_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nama      10 non-null     object
#  1   nilai     10 non-null     int64
#  2   jurusan   10 non-null     object
#  3   ekonomi   10 non-null     object
#  4   beasiswa  10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 480.0+ bytes

# %% [markdown]
# Sudah tidak ada data terduplikasi maupun missing value dalam data. Selanjutnya, kita akan mengubah format data menjadi format yang sesuai.

# %% [markdown]
# ### Categorical Encoding

# %% [markdown]
# Categorical Encoding merupakan proses mengganti suatu nilai kategorikal dengan suatu nilai numerik.
#
# Dalam Python, agar data bisa digunakan dalam proses machine learning, data-data yang berupa objek/string perlu diubah menjadi integer terlebih dahulu.

# %%
# Mencari kategori apa saja pada sebuah kolom
kategori_jurusan = dk_new['jurusan'].unique()
kategori_ekonomi = dk_new['ekonomi'].unique()
kategori_beasiswa = dk_new['beasiswa'].unique()

print('Nilai kategori dalam kolom jurusan:', kategori_jurusan)
print('Nilai kategori dalam kolom ekonomi:', kategori_ekonomi)
print('Nilai kategori dalam kolom beasiswa:', kategori_beasiswa)
# Out:
# Nilai kategori dalam kolom jurusan: ['IPA' 'IPS']
# Nilai kategori dalam kolom ekonomi: ['Mampu' 'Kurang Mampu' 'Menengah']
# Nilai kategori dalam kolom beasiswa: ['Tidak' 'Ya']

# %% [markdown]
# ![Label encoding vs One hot encoding](https://miro.medium.com/v2/resize:fit:700/0*T5jaa2othYfXZX9W.)

# %% [markdown]
# #### Menggunakan Label Encoding
#
# **Label Encoding** memetakan tiap kategori ke dalam angka numerik, mulai dari 1, 2, 3, dst.

# %% [markdown]
# >> Opsi 1 : Mengganti secara manual

# %% [markdown]
# `replace()` dapat digunakan untuk mengubah nilai dalam data, melakukan encoding secara manual

# %%
# Menggunakan replace()
dk_encoded = dk_new.replace({'jurusan' : {'IPA': 1 , 'IPS': 2}})
dk_encoded.head()
# Out:
# C:\Users\luxha\AppData\Local\Temp\ipykernel_26172\2986356656.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dk_encoded = dk_new.replace({'jurusan' : {'IPA': 1 , 'IPS': 2}})
#       nama  nilai  jurusan       ekonomi beasiswa
# 0     Aida     75        1         Mampu    Tidak
# 1     Beta     66        1  Kurang Mampu       Ya
# 2  Charlie     80        2  Kurang Mampu       Ya
# 3     Doni     33        1      Menengah    Tidak
# 4      Eka     80        2      Menengah    Tidak

# %% [markdown]
# Kita juga dapat menggunakan `astype('category)` untuk mengubah format data menjadi kategorikal, kemudian menggunakan `cat.codes` untuk mendapat encoding dari kategori tersebut

# %%
dk_encoded['beasiswa'] = dk_encoded['beasiswa'].astype('category')
dk_encoded['beasiswa'] = dk_encoded['beasiswa'].cat.codes
dk_encoded
# Out:
#       nama  nilai  jurusan       ekonomi  beasiswa
# 0     Aida     75        1         Mampu         0
# 1     Beta     66        1  Kurang Mampu         1
# 2  Charlie     80        2  Kurang Mampu         1
# 3     Doni     33        1      Menengah         0
# 4      Eka     80        2      Menengah         0
# 5    Firda     99        1         Mampu         1
# 6     Gina     67        1  Kurang Mampu         0
# 7     Hera     56        1         Mampu         1
# 8    Indra     89        1         Mampu         0
# 9    Janet     75        1      Menengah         1

# %% [markdown]
# #### Menggunakan One Hot Encoding

# %% [markdown]
# One Hot Encoding dilakukan untuk memetakan setiap kategori ke dalam nilai 0 dan 1 (berarti True/False). Data akan memiliki kolom tambahan sesuai dengan jumlah kategori.

# %% [markdown]
# Library pandas menyediakan method untuk melakukan one hot encoding. `get_dummies()` memberikan one hot encoding dari kolom yang diberikan.

# %%
one_hot = pd.get_dummies(dk_new['ekonomi'])
one_hot.head()
# Out:
#    Kurang Mampu  Mampu  Menengah
# 0         False   True     False
# 1          True  False     False
# 2          True  False     False
# 3         False  False      True
# 4         False  False      True

# %%
# Menggabungkan kolom "Kurang Mampu" dan "Mampu" ke dataset
dk_encoded = dk_encoded.join(one_hot)
dk_encoded.head()
# Out:
#       nama  nilai  jurusan       ekonomi  beasiswa  Kurang Mampu  Mampu  \
# 0     Aida     75        1         Mampu         0         False   True
# 1     Beta     66        1  Kurang Mampu         1          True  False
# 2  Charlie     80        2  Kurang Mampu         1          True  False
# 3     Doni     33        1      Menengah         0         False  False
# 4      Eka     80        2      Menengah         0         False  False
#
#    Menengah
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True

# %%
# menghilangkan kolom "ekonomi" karena tidak dipakai
dk_encoded = dk_encoded.drop(columns = 'ekonomi')
dk_encoded.head()
# Out:
#       nama  nilai  jurusan  beasiswa  Kurang Mampu  Mampu  Menengah
# 0     Aida     75        1         0         False   True     False
# 1     Beta     66        1         1          True  False     False
# 2  Charlie     80        2         1          True  False     False
# 3     Doni     33        1         0         False  False      True
# 4      Eka     80        2         0         False  False      True

# %% [markdown]
# ### Outlier

# %% [markdown]
# Outlier adalah data berjenis data interval, yang nilainya berbeda secara signifikan dari keseluruhan data. Outlier memiliki dampak besar pada hasil analisis statistik atau pemodelan data. Untuk mendeteksi outlier, kita dapat menggunakan box plot.

# %%
# Box Plot
plt.figure(figsize = (5, 5))
dk_encoded['nilai'].plot(kind="box")
plt.show()

# %% [markdown]
# ### Menghapus Outlier
#
# It is suggested to remove outlier as these **excessively high/low values may not represent actual data** hence introducing **bias** to the model.
#
# Other reference:
# https://medium.com/analytics-vidhya/how-to-remove-outliers-for-machine-learning-24620c4657e8

# %% [markdown]
# #### 1. Menggunakan z score

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Z-score berfungsi untuk mengetahui apakah suatu nilai lebih rendah dari nilai rataan dalam satu dataset dan mengukur seberapa jauh dari rataan

# %%
dk_mean = dk_encoded['nilai'].mean()
dk_std = dk_encoded['nilai'].std()
print("Nilai rata-rata: {0}\nNilai Standard Deviasi: {1}".format(dk_mean, dk_std))
# Out:
# Nilai rata-rata: 72.0
# Nilai Standard Deviasi: 18.263503375736967

# %%
# threshold value for z-score
threshold = 1

# %% [markdown]
# Threshold value 1 berarti kita hanya menyimpan nilai yang berjarak dalam 1 standar deviasi dari rataan.

# %%
outlier = []

for i in dk_encoded['nilai']:
    z = (i-dk_mean)/dk_std
    if abs(z) > threshold:
        outlier.append(i)

print('Outlier dari kolom nilai adalah', outlier)
# Out:
# Outlier dari kolom nilai adalah [33, 99]

# %% [markdown]
# Z-score juga dapat dihitung dengan library Scipy, dengan `stats.zscore()`

# %%
from scipy import stats
dk_encoded['z_score'] = stats.zscore(dk_encoded['nilai'])
dk_encoded.head()
# Out:
#       nama  nilai  jurusan  beasiswa  Kurang Mampu  Mampu  Menengah   z_score
# 0     Aida     75        1         0         False   True     False  0.173147
# 1     Beta     66        1         1          True  False     False -0.346295
# 2  Charlie     80        2         1          True  False     False  0.461726
# 3     Doni     33        1         0         False  False      True -2.250916
# 4      Eka     80        2         0         False  False      True  0.461726

# %%
dk_no_outliers = dk_encoded.loc[dk_encoded['z_score'].abs() < threshold]
dk_no_outliers = dk_no_outliers.reset_index(drop=True)
dk_no_outliers
# Out:
#       nama  nilai  jurusan  beasiswa  Kurang Mampu  Mampu  Menengah   z_score
# 0     Aida     75        1         0         False   True     False  0.173147
# 1     Beta     66        1         1          True  False     False -0.346295
# 2  Charlie     80        2         1          True  False     False  0.461726
# 3      Eka     80        2         0         False  False      True  0.461726
# 4     Gina     67        1         0          True  False     False -0.288579
# 5     Hera     56        1         1         False   True     False -0.923453
# 6    Indra     89        1         0         False   True     False  0.981168
# 7    Janet     75        1         1         False  False      True  0.173147

# %% [markdown]
# #### 2. Inter Quartile Range (IQR)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# IQR (interquartile range) adalah jarak antara kuartil bawah dan kuartil atas. Dalam metode IQR, kita dapat menemukan outlier dengan menghitung batas bawah dan batas atas. Data diluar batas atas dan bawah akan dianggap sebagai outlier.

# %%
def outlier_treatment(datacolumn):
  sorted(datacolumn)  # Memastikan data sudah urut
  Q1, Q3 = np.percentile(datacolumn , [25,75])
  IQR = Q3 - Q1
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)
  return lower_range, upper_range

# %%
lowerbound, upperbound = outlier_treatment(dk_encoded.nilai)
print("Batas bawah: {0}\nBatas atas: {1}".format(lowerbound, upperbound))
# Out:
# Batas bawah: 45.625
# Batas atas: 100.625

# %%
# Cek data yang menjadi outlier
dk_encoded[(dk_encoded.nilai < lowerbound) | (dk_encoded.nilai > upperbound)]
# Out:
#    nama  nilai  jurusan  beasiswa  Kurang Mampu  Mampu  Menengah   z_score
# 3  Doni     33        1         0         False  False      True -2.250916

# %%
# Menghapus outlier
dk_no_outlier = dk_encoded.drop(dk_encoded[(dk_encoded.nilai < lowerbound) | (dk_encoded.nilai > upperbound)].index)
dk_no_outlier
# Out:
#       nama  nilai  jurusan  beasiswa  Kurang Mampu  Mampu  Menengah   z_score
# 0     Aida     75        1         0         False   True     False  0.173147
# 1     Beta     66        1         1          True  False     False -0.346295
# 2  Charlie     80        2         1          True  False     False  0.461726
# 4      Eka     80        2         0         False  False      True  0.461726
# 5    Firda     99        1         1         False   True     False  1.558326
# 6     Gina     67        1         0          True  False     False -0.288579
# 7     Hera     56        1         1         False   True     False -0.923453
# 8    Indra     89        1         0         False   True     False  0.981168
# 9    Janet     75        1         1         False  False      True  0.173147

# %% [markdown]
# ## **4. Eksplorasi Data**
# Eksplorasi data adalah kegiatan untuk menggali dan memahami inferensi yang terdapat pada suatu kumpulan data. Dalam konteks data analytics maupun data science, eksplorasi data mencakup mencari tren dan melakukan analisis statistik dasar seperti mean, median, dsb.

# %% [markdown]
# ![Exploratory Data Analysis](https://miro.medium.com/v2/resize:fit:1400/1*03D9umtAeoGnFXYH-Ycm8A.png)

# %% [markdown]
# ### Summary Statistics

# %%
# data_iris = pd.read_csv('iris_dataset.csv').drop('Id', axis=1)

# %% [markdown]
# > Melihat seluruh isi dataset

# %%
# untuk melihat isi dataset
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# > Melihat sebagian isi dataset

# %%
data_iris.head() # default: FIRST 5 ROWS in DataFrame
# data_iris.head(10) # see FIRST 10 ROWS
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data_iris.tail() # default: LAST 5 ROWS in DataFrame
# data_iris.tail(10) # see LAST 10 ROWS
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %% [markdown]
# > Melihat tipe data dan Non-Null count dari masing-masing kolom

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# > Analisa statistik

# %%
# menampilkan mean, standar deviasi, min, kuartil (25%, 50%, 75%) dan max (pandas)
data_iris.describe()
# data_iris.describe(include='all') # statistical description of ALL COLUMNS, both NUMERIC/STRING datatype
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# menampilkan nilai unik (distinct values) di suatu kolom, biasanya digunakan untuk melihat nilai kategorikal
data_iris['species'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
# menampilkan Counts dari tiap nilai unik di suatu kolom
data_iris['species'].value_counts()
# Out:
# species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
# menampilkan rata-rata tiap kolom
data_iris['sepal_length'].mean()
data_iris['sepal_width'].mean()
data_iris['petal_length'].mean()
data_iris['petal_width'].mean()
data_iris.drop('species', axis=1).mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
# menampilkan rata-rata suatu kolom
data_iris['sepal_length'].mean()
# Out:
# 5.843333333333334

# %%
# menampilkan nilai modus
data_iris.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.0           1.4          0.2      Setosa
# 1           NaN          NaN           1.5          NaN  Versicolor
# 2           NaN          NaN           NaN          NaN   Virginica

# %%
# menampilkan nilai minimum
data_iris.min()
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         Setosa
# dtype: object

# %%
# menampilkan nilai maksimum
data_iris.max()
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         Virginica
# dtype: object

# %%
# menampilkan percentile (numpy)
data_iris.drop('species', axis=1).quantile(0.25) # percentile ke-25
# Out:
# sepal_length    5.1
# sepal_width     2.8
# petal_length    1.6
# petal_width     0.3
# Name: 0.25, dtype: float64

# %%
# menampilkan percentile (numpy)
data_iris.drop('species', axis=1).quantile(0.5) #median atau percentile ke-50
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# Name: 0.5, dtype: float64

# %%
# menampilkan median
data_iris.drop('species', axis=1).median()
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
# menampilkan standar deviasi (numpy)
data_iris.drop('species', axis=1).std()
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
# menampilkan range
min = data_iris["petal_length"].min()
max = data_iris["petal_length"].max()
range = max - min
print("range :", range)
# Out:
# range : 5.9

# %% [markdown]
# ### Visualisasi
#
# Visualisasi data ditujukan untuk mengetahui, antara lain:
# * **distribusi/sebaran data** (e.g. skewness, outlier)
# * **korelasi antar kolom** (*good* when there is a *strong corr. between features & target*; while <u>strong corr. *between 2 features* means that those are redundant features, hence just choose one from it</u>)
# * **class separability** yaitu seberapa jauh jarak data antarkelas. semakin jauh jarak antarkelas, maka semakin mudah dibedakan sehingga kemungkinan model ML akan semakin mudah untuk mengklasifikasikannya  \[khusus pada problem klasifikasi]

# %% [markdown]
# ![link text](https://media.licdn.com/dms/image/C5612AQGnFykY2Fj3EA/article-cover_image-shrink_600_2000/0/1538501313657?e=2147483647&v=beta&t=sPWqCDNGEHyrF7BcOkrBdlR4BIE_dbCV5FWS2bjzR9M)

# %% [markdown]
# #### Analisa Univariat

# %%
# menampilkan histogram
plt.figure(figsize = (10, 10))
data_iris.hist()
plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
# menampilkan histogram custom
plt.figure(figsize = (5, 5))  # Ukuran gambar
x = data_iris["sepal_width"]  # Data yang ingin divisualisasikan
plt.hist(x, color = "red")  # Jenis visualisasi, dengan argument tambahan untuk memberi warna
plt.title("Sepal Width")  # Judul visualisasi
plt.xlabel("Sepal Width (cm)")  # Label sumbu x
plt.ylabel("Count")  # Label sumbu y
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Histogram adalah salah satu jenis grafik atau diagram statistik yang digunakan untuk menggambarkan distribusi dari suatu data numerik.

# %%
# Box Plot
data_iris['sepal_width'].plot(kind = "box")
plt.show()

# %% [markdown]
# Box plot memberikan gambaran tentang statistik deskriptif kunci dari data, seperti kuartil, median, serta outlier.

# %%
# Pie Chart
data_iris['species'].value_counts().plot.pie(autopct='%.2f%%',shadow=True,figsize=(5,5))
plt.show()

# %% [markdown]
# Pie chart atau diagram lingkaran adalah jenis grafik yang digunakan untuk memvisualisasikan data kategori atau komponen sebagai bagian dari keseluruhan.

# %% [markdown]
# ####Analisa Bivariat

# %% [markdown]
# Scatter matrix adalah matriks yang berisi sejumlah scatter plots yang dibuat antara semua pasangan variabel dalam dataset.

# %%
# Scatter matrix
from pandas.plotting import scatter_matrix
scatter_matrix(data_iris, figsize = (15,15))
plt.show()

# %%
sns.pairplot(data=data_iris, hue='species')

# %%
# Memberikan warna pada masing-masing class
setosa = data_iris[data_iris['species'] == 'Setosa']
versicolor = data_iris[data_iris['species'] == 'Versicolor']
virginica = data_iris[data_iris['species'] == 'Virginica']

plt.scatter(setosa['sepal_length'], setosa['sepal_width'], c='r')
plt.scatter(versicolor['sepal_length'], versicolor['sepal_width'], c = 'g')
plt.scatter(virginica['sepal_length'], virginica['sepal_width'], c = 'b')
plt.show()

# %% [markdown]
# Heatmap adalah jenis grafik yang digunakan untuk memvisualisasikan data dalam bentuk matriks dengan representasi warna.
#
# Semakin intens warna suatu kotak dalam heatmap, maka semakin berkorelasi pula data yang digunakan.

# %%
# Heatmap
plt.figure(figsize=(7,4))
sns.heatmap(data_iris.drop("species", axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## (Optional) Praproses data teks

# %% [markdown]
# Dalam section ini, kita akan sekilas mencari tahu, bagaimana cara untuk memproses data teks dalam problem klasifikasi.

# %%
# Importing libraries
import csv
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Downloading data
# !wget --no-check-certificate \
    https://storage.googleapis.com/learning-datasets/bbc-text.csv \
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Loading data
with open("bbc-text.csv", 'r') as csvfile:
    print(f"First line (header) looks like this:\n\n{csvfile.readline()}")
    print(f"Each data point looks like this:\n\n{csvfile.readline()}")
# Out:
# First line (header) looks like this:
#
# category,text
#
# Each data point looks like this:
#
# ...

# %% [markdown]
# Setiap titik data terdiri dari kategori artikel berita diikuti dengan koma, lalu teks artikel sebenarnya.

# %% [markdown]
# ### Removing Stopwords

# %% [markdown]
# Salah satu langkah penting ketika memproses data teks adalah menghapus stopwords. Stopwords adalah kata-kata yang paling umum dalam bahasa dan jarang memberikan informasi yang berguna untuk proses klasifikasi.

# %%
def remove_stopwords(sentence):
    # List of stopwords
    stopwords = ["a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]

    # Sentence converted to lowercase-only
    sentence = sentence.lower()

    words = sentence.split()
    cleaned_words = [word for word in words if word not in stopwords]
    sentence = ' '.join(cleaned_words)

    return sentence

# %%
remove_stopwords("I am about to go to the store and get any snack")
# Out:
# 'go store get snack'

# %% [markdown]
# ### Reading the raw data

# %% [markdown]
# Sekarang kita perlu membaca data dari file csv.

# %%
def parse_data_from_file(filename):
    sentences = []
    labels = []

    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader, None)

        for row in reader:
            sentences.append(remove_stopwords(row[1]))
            labels.append(remove_stopwords(row[0]))

    return sentences, labels

# %%
# With original dataset
sentences, labels = parse_data_from_file("bbc-text.csv")

print(f"There are {len(sentences)} sentences in the dataset.\n")
print(f"First sentence has {len(sentences[0].split())} words (after removing stopwords).\n")
print(f"There are {len(labels)} labels in the dataset.\n")
print(f"The first 5 labels are {labels[:5]}\n\n")
# Out:
# There are 2225 sentences in the dataset.
#
# First sentence has 436 words (after removing stopwords).
#
# There are 2225 labels in the dataset.
#
# The first 5 labels are ['tech', 'business', 'sport', 'sport', 'entertainment']

# %% [markdown]
# ### Mengenal NLTK
#
# NLTK (Natural Language Toolkit) adalah perpustakaan atau library yang berisi kumpulan program dan alat untuk pemrosesan bahasa alami (Natural Language Processing atau NLP) menggunakan Python.
#
# Dengan panduan praktis yang memperkenalkan dasar-dasar pemrograman di samping topik linguistik komputasi, ditambah dokumentasi API yang komprehensif, NLTK cocok digunakan oleh linguis, insinyur, siswa, pendidik, peneliti, dan pengguna industri

# %% [markdown]
# ### Stemming & lemmatizating
#
# Stemming adalah proses mengembalikan kata-kata ke bentuk dasarnya dengan menghilangkan imbuhan, baik itu prefiks maupun sufiks. Proses ini penting dalam Natural Language Processing (NLP) untuk mempersiapkan data teks sebelum diproses lebih lanjut.

# %% [markdown]
# ### stemmer indonesia

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."

hasil = stemmer.stem(kalimat)
print(hasil)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#       3 factory = StemmerFactory()
#       4 stemmer = factory.create_stemmer()
#
# ModuleNotFoundError: No module named 'Sastrawi'

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# ...
#   Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached h5py-3.11.0-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached ml_dtypes-0.4.0-cp312-cp312-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached protobuf-4.25.4-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# ...
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# ...

# %% [markdown]
# ### stemmer En

# %%
from nltk.stem import PorterStemmer

# Membuat objek PorterStemmer
ps = PorterStemmer()

# Daftar kata yang akan di-stem
kata = ["program", "programs", "programer", "programming", "programmers"]

# Melakukan stemming pada setiap kata
for k in kata:
    print(k, " : ", ps.stem(k))
# Out:
# program  :  program
# programs  :  program
# programer  :  program
# programming  :  program
# programmers  :  programm

# %% [markdown]
# ### Using the Tokenizer

# %% [markdown]
# Proses selanjutnya adalah tokenisasi. Tokenisasi digunakan dalam pemrosesan bahasa alami untuk membagi paragraf dan kalimat menjadi unit-unit yang lebih kecil sehingga lebih mudah diberi makna. Langkah pertama dari proses NLP adalah mengumpulkan data (kalimat) dan memecahnya menjadi bagian-bagian (kata-kata) yang dapat dimengerti.
#
# ![Tokenization](https://miro.medium.com/v2/resize:fit:1200/1*UhfwmhMN9sdfcWIbO5_tGg.jpeg)

# %%
def fit_tokenizer(sentences):
    # Instantiate the Tokenizer class by passing in the oov_token argument
    tokenizer = Tokenizer(oov_token='<OOV>')
    # Fit on the sentences
    tokenizer.fit_on_texts(sentences)
    return tokenizer

# %%
tokenizer = fit_tokenizer(sentences)
word_index = tokenizer.word_index

print(f"Vocabulary contains {len(word_index)} words\n")
print("<OOV> token included in vocabulary" if "<OOV>" in word_index else "<OOV> token NOT included in vocabulary")
# Out:
# Vocabulary contains 29714 words
#
# <OOV> token included in vocabulary

# %% [markdown]
# Dalam melakukan pemodelan, model harus mendapat input yang memiliki bentuk dan ukuran yang sama. Namun, saat kita melakukan pra-pemrosesan dan menggunakan teks sebagai masukan untuk model kita, tidak semua kalimat memiliki panjang yang sama. Beberapa kalimat ada yang lebih panjang atau lebih pendek. Kita perlu memiliki input dengan ukuran yang sama, maka perlu dilakukan padding/truncating. Kita akan mencoba melakukan padding dengan kode dibawah ini.

# %%
def get_padded_sequences(tokenizer, sentences):
    # Convert sentences to sequences
    sequences = tokenizer.texts_to_sequences(sentences)

    # Pad the sequences using the post padding strategy
    padded_sequences = pad_sequences(sequences, padding='post')

    return padded_sequences

# %%
padded_sequences = get_padded_sequences(tokenizer, sentences)
print(f"First padded sequence looks like this: \n\n{padded_sequences[0]}\n")
print(f"Numpy array of all sequences has shape: {padded_sequences.shape}\n")
print(f"This means there are {padded_sequences.shape[0]} sequences in total and each one has a size of {padded_sequences.shape[1]}")
# Out:
# First padded sequence looks like this:
#
# [  96  176 1157 ...    0    0    0]
#
# Numpy array of all sequences has shape: (2225, 2438)
#
# This means there are 2225 sequences in total and each one has a size of 2438

# %% [markdown]
# Label juga perlu ditokenisasi.

# %%
def tokenize_labels(labels):
    # Instantiate the Tokenizer class
    # No need to pass additional arguments since you will be tokenizing the labels
    label_tokenizer = Tokenizer()

    # Fit the tokenizer to the labels
    label_tokenizer.fit_on_texts(labels)

    # Save the word index
    label_word_index = label_tokenizer.word_index

    # Save the sequences
    label_sequences = label_tokenizer.texts_to_sequences(labels)

    return label_sequences, label_word_index

# %%
label_sequences, label_word_index = tokenize_labels(labels)
print(f"Vocabulary of labels looks like this {label_word_index}\n")
print(f"First ten sequences {label_sequences[:10]}\n")
# Out:
# Vocabulary of labels looks like this {'sport': 1, 'business': 2, 'politics': 3, 'tech': 4, 'entertainment': 5}
#
# First ten sequences [[4], [2], [1], [1], [5], [3], [3], [1], [1], [5]]

# %% [markdown]
# Setelah tokenisasi dan padding, maka data kita siap untuk digunakan dalam proses pemodelan!

# %% [markdown]
# ## Conclusion

# %% [markdown]
# *Cleaning and exploring data usually go hand in hand. That part of the process is iterative: you find something, understand it, if necessary clean it and keep exploring until you're happy you've got a data set that you understand and is useful.*

# %% [markdown]
# Please fill out this form for your feedback during today's session: [Feedback Tutorial 1](https://forms.gle/G5mrcYvpa7K9hsqt8)
#
# Any questions? Want to discuss? Feel free to contact us:
#
# Leon - [082306071010](https://wa.me/6282306071010)
#
# Mauritz - [081232557720](https://wa.me/6281232557720)
