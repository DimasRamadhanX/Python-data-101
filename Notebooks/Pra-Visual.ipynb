# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df= pd.read_csv("C:/Users/luxha/Python data 101/Data Buat Latihan/biking/hour.csv")

# %%
df[df['day']=='Sunday'].head(10)
# Out:
#     instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 24       25  2011-01-02       1   0     1   0        0        0           0
# 25       26  2011-01-02       1   0     1   1        0        0           0
# 26       27  2011-01-02       1   0     1   2        0        0           0
# 27       28  2011-01-02       1   0     1   3        0        0           0
# 28       29  2011-01-02       1   0     1   4        0        0           0
# 29       30  2011-01-02       1   0     1   6        0        0           0
# 30       31  2011-01-02       1   0     1   7        0        0           0
# 31       32  2011-01-02       1   0     1   8        0        0           0
# 32       33  2011-01-02       1   0     1   9        0        0           0
# 33       34  2011-01-02       1   0     1  10        0        0           0
#
#     weathersit  temp   atemp   hum  windspeed  casual  registered  cnt     day
# ...

# %%
def get_day_name(date_str):
    date_obj = datetime.strptime(date_str, '%Y-%m-%d')
    return date_obj.strftime('%A')

# %%
df['day'] = df['dteday'].apply(get_day_name) ##untuk masukan data mengenai hari

# %%
def detect_outliers(data):
    # Konversi data menjadi numpy array untuk kemudahan perhitungan
    data = np.array(data)
    
    # Hitung Q1 dan Q3
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    
    # Hitung IQR
    IQR = Q3 - Q1
    
    # Tentukan batas bawah dan batas atas
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Deteksi outlier
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    
    return outliers

# Contoh data
data = [10, 12, 13, 15, 15, 16, 18, 20, 22, 23, 24, 30, 100]

# Panggil fungsi
outliers = detect_outliers(data)

print("Outliers:", outliers)
# Out:
# Outliers: [100]
